# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 uninstall keras
# !pip3 install keras==2.0.8
# Out:
# Uninstalling Keras-2.4.3:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/Keras-2.4.3.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/docs/*
#     /usr/local/lib/python3.6/dist-packages/keras/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.6/dist-packages/docs/md_autogen.py
#     /usr/local/lib/python3.6/dist-packages/docs/update_docs.py
# Proceed (y/n)? y
#   Successfully uninstalled Keras-2.4.3
# ...
#      |████████████████████████████████| 276kB 27.5MB/s
# ...
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.8 which is incompatible.
# ...

# %%
# %tensorflow_version 1.x
import time
start=time.time()
# !python3 /content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/samples/train/inference_video.py --input /content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/samples/train/video/final_test.mp4 --weight /content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/logs/name20201130T0307/mask_rcnn_name_0049.h5 --output /content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/samples/train/video_output/final_output.mp4
print('elapsed time',time.time()-start)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# *** No instances to display ***
#
# 6609.0/8431.0
#
# *** No instances to display ***
#
# 6610.0/8431.0
#
# *** No instances to display ***
#
# 6611.0/8431.0
#
# *** No instances to display ***
#
# 6612.0/8431.0
#
# *** No instances to display ***
#
# 6613.0/8431.0
#
# *** No instances to display ***
#
# 6614.0/8431.0
#
# *** No instances to display ***
#
# 6615.0/8431.0
#
# *** No instances to display ***
#
# 6616.0/8431.0
#
# *** No instances to display ***
#
# 6617.0/8431.0
#
# *** No instances to display ***
#
# 6618.0/8431.0
#
# *** No instances to display ***
#
# 6619.0/8431.0
#
# *** No instances to display ***
#
# 6620.0/8431.0
#
# *** No instances to display ***
#
# 6621.0/8431.0
#
# *** No instances to display ***
#
# 6622.0/8431.0
#
# *** No instances to display ***
#
# 6623.0/8431.0
#
# *** No instances to display ***
#
# 6624.0/8431.0
#
# *** No instances to display ***
#
# 6625.0/8431.0
#
# *** No instances to display ***
#
# ...

# %%
# %tensorflow_version 1.x
# !!python3 /content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/samples/train/inference.py --input /content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/images/ --weight /content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/logs/mask_rcnn_name.h5 --output /content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/samples/train/output/

# %%
# %tensorflow_version 1.x
# !python3 /content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/samples/train/train.py train --dataset=/content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/samples/train --weight=coco

# %%
# %tensorflow_version 1.x
import time
start=time.time()
# !python3 /content/drive/MyDrive/mrcnn/Mask_RCNN-master/Mask_RCNN-master/process_video.py
print('elapsed time',time.time()-start)
